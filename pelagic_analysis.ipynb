# %%
import pandas as pd
import numpy as np
import zipfile
import spkly

# %%
zip = zipfile.ZipFile('data/Teleost_Especes_Pelagiques_Abondance_2009-2018.zip')
zip.namelist()
# Out:
# ['Abondance_Nord_2009a2018.csv', 'Abondance_Sud_2009a2018.csv']

# %%
north_fish, south_fish = pd.read_csv(zip.open(zip.namelist()[0])), pd.read_csv(zip.open(zip.namelist()[1]))
spkly.display(north_fish.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Station<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#pb5e76af94e)" d="M 14.809091 33.144545 L 52.854545 26.967273 L 90.9 20.79 L 128.945455 14.612727 L 166.990909 8.435455 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="pb5e76af94e">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>Longitude<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#p963199db24)" d="M 14.809091 8.435455 L 52.854545 12.737934 L 90.9 16.944963 L 128.945455 29.688514 L 166.990909 33.144545 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="p963199db24">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>Latitude<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#p4f7d49a8ea)" d="M 14.809091 33.144545 L 52.854545 23.359955 L 90.9 30.645873 L 128.945455 22.099364 L 166.990909 8.435455 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="p4f7d49a8ea">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>Profondeur/Depth<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#pb2a6cd46af)" d="M 14.809091 17.897228 L 52.854545 9.821574 L 90.9 8.435455 L 128.945455 33.144545 L 166.990909 24.104634 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="pb2a6cd46af">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>AMSPP<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#pd10598f225)" d="M 14.809091 20.79 L 52.854545 20.79 L 90.9 20.79 L 128.945455 20.79 L 166.990909 20.79 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="pd10598f225">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>ARRIS<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#ped5db16f8a)" d="M 14.809091 8.435455 L 52.854545 31.869238 L 90.9 24.775337 L 128.945455 33.144545 L 166.990909 22.782669 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="ped5db16f8a">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>ARSIL<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#p21992399ff)" d="M 14.809091 20.79 L 52.854545 20.79 L 90.9 20.79 L 128.945455 20.79 L 166.990909 20.79 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="p21992399ff">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>BOSAI<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#p10c99d17cc)" d="M 14.809091 20.79 L 52.854545 20.79 L 90.9 20.79 L 128.945455 20.79 L 166.990909 20.79 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="p10c99d17cc">

# %%
spkly.display(south_fish.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Station<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#p8e3413ee57)" d="M 14.809091 33.144545 L 52.854545 26.967273 L 90.9 20.79 L 128.945455 14.612727 L 166.990909 8.435455 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="p8e3413ee57">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>Longitude<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#p4fa16c1cf0)" d="M 14.809091 25.303454 L 52.854545 33.144545 L 90.9 23.731558 L 128.945455 19.346798 L 166.990909 8.435455 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="p4fa16c1cf0">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>Latitude<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#p1979723dc4)" d="M 14.809091 8.435455 L 52.854545 32.36013 L 90.9 24.254503 L 128.945455 33.144545 L 166.990909 31.935239 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="p1979723dc4">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>Profondeur/Depth<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#p7ece0ddbe2)" d="M 14.809091 33.144545 L 52.854545 30.673636 L 90.9 23.260909 L 128.945455 8.435455 L 166.990909 15.848182 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="p7ece0ddbe2">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>AMSPP<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#p297dd73150)" d="M 14.809091 20.79 L 52.854545 20.79 L 90.9 20.79 L 128.945455 20.79 L 166.990909 20.79 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="p297dd73150">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>ARRIS<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#pff6f0e0049)" d="M 14.809091 20.79 L 52.854545 20.79 L 90.9 20.79 L 128.945455 20.79 L 166.990909 20.79 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="pff6f0e0049">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>ARSIL<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#pf585911bf4)" d="M 14.809091 20.79 L 52.854545 20.79 L 90.9 20.79 L 128.945455 20.79 L 166.990909 20.79 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="pf585911bf4">   <rect height="27.18" width="167.4" x="7.2" y="7.2"/>  </clipPath> </defs></svg></th>
#       <th>BOSAI<?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="41.58pt" version="1.1" viewBox="0 0 181.8 41.58" width="181.8pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <defs>  <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}  </style> </defs> <g id="figure_1">  <g id="patch_1">   <path d="M 0 41.58 L 181.8 41.58 L 181.8 0 L 0 0 z" style="fill:#ffffff;"/>  </g>  <g id="axes_1">   <g id="line2d_1">    <path clip-path="url(#pdcaf71d8a3)" d="M 14.809091 20.79 L 52.854545 20.79 L 90.9 20.79 L 128.945455 20.79 L 166.990909 20.79 " style="fill:none;stroke:#1f77b4;stroke-linecap:square;stroke-width:1.5;"/>   </g>  </g> </g> <defs>  <clipPath id="pdcaf71d8a3">   <rect height="27.18
