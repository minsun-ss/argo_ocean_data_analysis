# %%
#May require to pip install netCDF4

# %% [markdown]
# Documentation: http://www.odip.org/documents/odip/downloads/20/argo-dm-user-manual.pdf
#
# NetCDF: https://unidata.github.io/netcdf4-python/netCDF4/index.html

# %%
import pandas as pd
import numpy as np
import netCDF4
#import urllib
#import xarray

# %%
# commented out for later etl to download straight from ftp, open, and push to db
# url='ftp://usgodae.org/pub/outgoing/argo/geo/atlantic_ocean/2020/08/20200801_prof.nc'
# f = urllib.request.urlopen(url)

# turns out you have to use netcdf4 - this is a multidimensional dataset, so flat array packages like xarray doesn't work
argo = netCDF4.Dataset('data/20200101_prof.nc')
argo.variables
# Out:
# {'DATA_TYPE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 DATA_TYPE(STRING16)
#      long_name: Data type
#      conventions: Argo reference table 1
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (16,)
#  filling on,
#  'FORMAT_VERSION': <class 'netCDF4._netCDF4.Variable'>
#  |S1 FORMAT_VERSION(STRING4)
#      long_name: File format version
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (4,)
#  filling on,
#  'HANDBOOK_VERSION': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HANDBOOK_VERSION(STRING4)
#      long_name: Data handbook version
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (4,)
#  filling on,
#  'REFERENCE_DATE_TIME': <class 'netCDF4._netCDF4.Variable'>
#  |S1 REFERENCE_DATE_TIME(DATE_TIME)
#      long_name: Date of reference for Julian days
#      conventions: YYYYMMDDHHMISS
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (14,)
#  filling on,
#  'DATE_CREATION': <class 'netCDF4._netCDF4.Variable'>
#  |S1 DATE_CREATION(DATE_TIME)
#      long_name: Date of file creation
#      conventions: YYYYMMDDHHMISS
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (14,)
#  filling on,
#  'DATE_UPDATE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 DATE_UPDATE(DATE_TIME)
#      long_name: Date of update of this file
#      conventions: YYYYMMDDHHMISS
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (14,)
#  filling on,
#  'PLATFORM_NUMBER': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PLATFORM_NUMBER(N_PROF, STRING8)
#      long_name: Float unique identifier
#      conventions: WMO float identifier : A9IIIII
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 8)
#  filling on,
#  'PROJECT_NAME': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PROJECT_NAME(N_PROF, STRING64)
#      long_name: Name of the project
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 64)
#  filling on,
#  'PI_NAME': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PI_NAME(N_PROF, STRING64)
#      long_name: Name of the principal investigator
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 64)
#  filling on,
#  'STATION_PARAMETERS': <class 'netCDF4._netCDF4.Variable'>
#  |S1 STATION_PARAMETERS(N_PROF, N_PARAM, STRING16)
#      long_name: List of available parameters for the station
#      conventions: Argo reference table 3
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 3, 16)
#  filling on,
#  'CYCLE_NUMBER': <class 'netCDF4._netCDF4.Variable'>
#  int32 CYCLE_NUMBER(N_PROF)
#      long_name: Float cycle number
#      conventions: 0...N, 0 : launch cycle (if exists), 1 : first complete cycle
#      _FillValue: 99999
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'DIRECTION': <class 'netCDF4._netCDF4.Variable'>
#  |S1 DIRECTION(N_PROF)
#      long_name: Direction of the station profiles
#      conventions: A: ascending profiles, D: descending profiles
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'DATA_CENTRE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 DATA_CENTRE(N_PROF, STRING2)
#      long_name: Data centre in charge of float data processing
#      conventions: Argo reference table 4
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 2)
#  filling on,
#  'DC_REFERENCE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 DC_REFERENCE(N_PROF, STRING32)
#      long_name: Station unique identifier in data centre
#      conventions: Data centre convention
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 32)
#  filling on,
#  'DATA_STATE_INDICATOR': <class 'netCDF4._netCDF4.Variable'>
#  |S1 DATA_STATE_INDICATOR(N_PROF, STRING4)
#      long_name: Degree of processing the data have passed through
#      conventions: Argo reference table 6
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 4)
#  filling on,
#  'DATA_MODE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 DATA_MODE(N_PROF)
#      long_name: Delayed mode or real time data
#      conventions: R : real time; D : delayed mode; A : real time with adjustment
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'PLATFORM_TYPE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PLATFORM_TYPE(N_PROF, STRING32)
#      long_name: Type of float
#      conventions: Argo reference table 23
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 32)
#  filling on,
#  'FLOAT_SERIAL_NO': <class 'netCDF4._netCDF4.Variable'>
#  |S1 FLOAT_SERIAL_NO(N_PROF, STRING32)
#      long_name: Serial number of the float
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 32)
#  filling on,
#  'FIRMWARE_VERSION': <class 'netCDF4._netCDF4.Variable'>
#  |S1 FIRMWARE_VERSION(N_PROF, STRING32)
#      long_name: Instrument firmware version
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 32)
#  filling on,
#  'WMO_INST_TYPE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 WMO_INST_TYPE(N_PROF, STRING4)
#      long_name: Coded instrument type
#      conventions: Argo reference table 8
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 4)
#  filling on,
#  'JULD': <class 'netCDF4._netCDF4.Variable'>
#  float64 JULD(N_PROF)
#      long_name: Julian day (UTC) of the station relative to REFERENCE_DATE_TIME
#      standard_name: time
#      units: days since 1950-01-01 00:00:00 UTC
#      conventions: Relative julian days with decimal part (as parts of day)
#      resolution: 999999.0
#      _FillValue: 999999.0
#      axis: T
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'JULD_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 JULD_QC(N_PROF)
#      long_name: Quality on date and time
#      conventions: Argo reference table 2
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'JULD_LOCATION': <class 'netCDF4._netCDF4.Variable'>
#  float64 JULD_LOCATION(N_PROF)
#      long_name: Julian day (UTC) of the location relative to REFERENCE_DATE_TIME
#      units: days since 1950-01-01 00:00:00 UTC
#      conventions: Relative julian days with decimal part (as parts of day)
#      resolution: 999999.0
#      _FillValue: 999999.0
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'LATITUDE': <class 'netCDF4._netCDF4.Variable'>
#  float64 LATITUDE(N_PROF)
#      long_name: Latitude of the station, best estimate
#      standard_name: latitude
#      units: degree_north
#      _FillValue: 99999.0
#      valid_min: -90.0
#      valid_max: 90.0
#      axis: Y
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'LONGITUDE': <class 'netCDF4._netCDF4.Variable'>
#  float64 LONGITUDE(N_PROF)
#      long_name: Longitude of the station, best estimate
#      standard_name: longitude
#      units: degree_east
#      _FillValue: 99999.0
#      valid_min: -180.0
#      valid_max: 180.0
#      axis: X
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'POSITION_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 POSITION_QC(N_PROF)
#      long_name: Quality on position (latitude and longitude)
#      conventions: Argo reference table 2
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'POSITIONING_SYSTEM': <class 'netCDF4._netCDF4.Variable'>
#  |S1 POSITIONING_SYSTEM(N_PROF, STRING8)
#      long_name: Positioning system
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 8)
#  filling on,
#  'PROFILE_PRES_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PROFILE_PRES_QC(N_PROF)
#      long_name: Global quality flag of PRES profile
#      conventions: Argo reference table 2a
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'PROFILE_PSAL_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PROFILE_PSAL_QC(N_PROF)
#      long_name: Global quality flag of PSAL profile
#      conventions: Argo reference table 2a
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'PROFILE_TEMP_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PROFILE_TEMP_QC(N_PROF)
#      long_name: Global quality flag of TEMP profile
#      conventions: Argo reference table 2a
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'VERTICAL_SAMPLING_SCHEME': <class 'netCDF4._netCDF4.Variable'>
#  |S1 VERTICAL_SAMPLING_SCHEME(N_PROF, STRING256)
#      long_name: Vertical sampling scheme
#      conventions: Argo reference table 16
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 256)
#  filling on,
#  'CONFIG_MISSION_NUMBER': <class 'netCDF4._netCDF4.Variable'>
#  int32 CONFIG_MISSION_NUMBER(N_PROF)
#      long_name: Unique number denoting the missions performed by the float
#      conventions: 1...N, 1 : first complete mission
#      _FillValue: 99999
#  unlimited dimensions:
#  current shape = (142,)
#  filling on,
#  'PRES': <class 'netCDF4._netCDF4.Variable'>
#  float32 PRES(N_PROF, N_LEVELS)
#      long_name: Sea water pressure, equals 0 at sea-level
#      standard_name: sea_water_pressure
#      _FillValue: 99999.0
#      units: decibar
#      valid_min: 0.0
#      valid_max: 12000.0
#      C_format: %15.1f
#      FORTRAN_format: F15.1
#      resolution: 99999.0
#      comment_on_resolution: resolution is unknown
#      axis: Z
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PRES_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PRES_QC(N_PROF, N_LEVELS)
#      long_name: quality flag
#      conventions: Argo reference table 2
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PRES_ADJUSTED': <class 'netCDF4._netCDF4.Variable'>
#  float32 PRES_ADJUSTED(N_PROF, N_LEVELS)
#      long_name: Sea water pressure, equals 0 at sea-level
#      standard_name: sea_water_pressure
#      _FillValue: 99999.0
#      units: decibar
#      valid_min: 0.0
#      valid_max: 12000.0
#      C_format: %15.1f
#      FORTRAN_format: F15.1
#      resolution: 99999.0
#      comment_on_resolution: resolution is unknown
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PRES_ADJUSTED_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PRES_ADJUSTED_QC(N_PROF, N_LEVELS)
#      long_name: quality flag
#      conventions: Argo reference table 2
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PRES_ADJUSTED_ERROR': <class 'netCDF4._netCDF4.Variable'>
#  float32 PRES_ADJUSTED_ERROR(N_PROF, N_LEVELS)
#      long_name: Contains the error on the adjusted values as determined by the delayed mode QC process
#      _FillValue: 99999.0
#      units: decibar
#      C_format: %15.4f
#      FORTRAN_format: F15.4
#      resolution: 99999.0
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PSAL': <class 'netCDF4._netCDF4.Variable'>
#  float32 PSAL(N_PROF, N_LEVELS)
#      long_name: Practical salinity
#      standard_name: sea_water_salinity
#      _FillValue: 99999.0
#      units: psu
#      valid_min: 2.0
#      valid_max: 41.0
#      C_format: %15.3f
#      FORTRAN_format: F15.3
#      resolution: 99999.0
#      comment_on_resolution: resolution is unknown
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PSAL_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PSAL_QC(N_PROF, N_LEVELS)
#      long_name: quality flag
#      conventions: Argo reference table 2
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PSAL_ADJUSTED': <class 'netCDF4._netCDF4.Variable'>
#  float32 PSAL_ADJUSTED(N_PROF, N_LEVELS)
#      long_name: Practical salinity
#      standard_name: sea_water_salinity
#      _FillValue: 99999.0
#      units: psu
#      valid_min: 2.0
#      valid_max: 41.0
#      C_format: %15.3f
#      FORTRAN_format: F15.3
#      resolution: 99999.0
#      comment_on_resolution: resolution is unknown
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PSAL_ADJUSTED_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PSAL_ADJUSTED_QC(N_PROF, N_LEVELS)
#      long_name: quality flag
#      conventions: Argo reference table 2
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PSAL_ADJUSTED_ERROR': <class 'netCDF4._netCDF4.Variable'>
#  float32 PSAL_ADJUSTED_ERROR(N_PROF, N_LEVELS)
#      long_name: Contains the error on the adjusted values as determined by the delayed mode QC process
#      _FillValue: 99999.0
#      units: psu
#      C_format: %15.4f
#      FORTRAN_format: F15.4
#      resolution: 99999.0
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'TEMP': <class 'netCDF4._netCDF4.Variable'>
#  float32 TEMP(N_PROF, N_LEVELS)
#      long_name: Sea temperature in-situ ITS-90 scale
#      standard_name: sea_water_temperature
#      _FillValue: 99999.0
#      units: degree_Celsius
#      valid_min: -2.5
#      valid_max: 40.0
#      C_format: %15.3f
#      FORTRAN_format: F15.3
#      resolution: 99999.0
#      comment_on_resolution: resolution is unknown
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'TEMP_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 TEMP_QC(N_PROF, N_LEVELS)
#      long_name: quality flag
#      conventions: Argo reference table 2
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'TEMP_ADJUSTED': <class 'netCDF4._netCDF4.Variable'>
#  float32 TEMP_ADJUSTED(N_PROF, N_LEVELS)
#      long_name: Sea temperature in-situ ITS-90 scale
#      standard_name: sea_water_temperature
#      _FillValue: 99999.0
#      units: degree_Celsius
#      valid_min: -2.5
#      valid_max: 40.0
#      C_format: %15.3f
#      FORTRAN_format: F15.3
#      resolution: 99999.0
#      comment_on_resolution: resolution is unknown
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'TEMP_ADJUSTED_QC': <class 'netCDF4._netCDF4.Variable'>
#  |S1 TEMP_ADJUSTED_QC(N_PROF, N_LEVELS)
#      long_name: quality flag
#      conventions: Argo reference table 2
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'TEMP_ADJUSTED_ERROR': <class 'netCDF4._netCDF4.Variable'>
#  float32 TEMP_ADJUSTED_ERROR(N_PROF, N_LEVELS)
#      long_name: Contains the error on the adjusted values as determined by the delayed mode QC process
#      _FillValue: 99999.0
#      units: degree_Celsius
#      C_format: %15.4f
#      FORTRAN_format: F15.4
#      resolution: 99999.0
#  unlimited dimensions:
#  current shape = (142, 2701)
#  filling on,
#  'PARAMETER': <class 'netCDF4._netCDF4.Variable'>
#  |S1 PARAMETER(N_PROF, N_CALIB, N_PARAM, STRING16)
#      long_name: List of parameters with calibration information
#      conventions: Argo reference table 3
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 3, 3, 16)
#  filling on,
#  'SCIENTIFIC_CALIB_EQUATION': <class 'netCDF4._netCDF4.Variable'>
#  |S1 SCIENTIFIC_CALIB_EQUATION(N_PROF, N_CALIB, N_PARAM, STRING256)
#      long_name: Calibration equation for this parameter
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 3, 3, 256)
#  filling on,
#  'SCIENTIFIC_CALIB_COEFFICIENT': <class 'netCDF4._netCDF4.Variable'>
#  |S1 SCIENTIFIC_CALIB_COEFFICIENT(N_PROF, N_CALIB, N_PARAM, STRING256)
#      long_name: Calibration coefficients for this equation
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 3, 3, 256)
#  filling on,
#  'SCIENTIFIC_CALIB_COMMENT': <class 'netCDF4._netCDF4.Variable'>
#  |S1 SCIENTIFIC_CALIB_COMMENT(N_PROF, N_CALIB, N_PARAM, STRING256)
#      long_name: Comment applying to this parameter calibration
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 3, 3, 256)
#  filling on,
#  'SCIENTIFIC_CALIB_DATE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 SCIENTIFIC_CALIB_DATE(N_PROF, N_CALIB, N_PARAM, DATE_TIME)
#      long_name: Date of calibration
#      conventions: YYYYMMDDHHMISS
#      _FillValue: b' '
#  unlimited dimensions:
#  current shape = (142, 3, 3, 14)
#  filling on,
#  'HISTORY_INSTITUTION': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HISTORY_INSTITUTION(N_HISTORY, N_PROF, STRING4)
#      long_name: Institution which performed action
#      conventions: Argo reference table 4
#      _FillValue: b' '
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142, 4)
#  filling on,
#  'HISTORY_STEP': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HISTORY_STEP(N_HISTORY, N_PROF, STRING4)
#      long_name: Step in data processing
#      conventions: Argo reference table 12
#      _FillValue: b' '
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142, 4)
#  filling on,
#  'HISTORY_SOFTWARE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HISTORY_SOFTWARE(N_HISTORY, N_PROF, STRING4)
#      long_name: Name of software which performed action
#      conventions: Institution dependent
#      _FillValue: b' '
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142, 4)
#  filling on,
#  'HISTORY_SOFTWARE_RELEASE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HISTORY_SOFTWARE_RELEASE(N_HISTORY, N_PROF, STRING4)
#      long_name: Version/release of software which performed action
#      conventions: Institution dependent
#      _FillValue: b' '
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142, 4)
#  filling on,
#  'HISTORY_REFERENCE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HISTORY_REFERENCE(N_HISTORY, N_PROF, STRING64)
#      long_name: Reference of database
#      conventions: Institution dependent
#      _FillValue: b' '
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142, 64)
#  filling on,
#  'HISTORY_DATE': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HISTORY_DATE(N_HISTORY, N_PROF, DATE_TIME)
#      long_name: Date the history record was created
#      conventions: YYYYMMDDHHMISS
#      _FillValue: b' '
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142, 14)
#  filling on,
#  'HISTORY_ACTION': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HISTORY_ACTION(N_HISTORY, N_PROF, STRING4)
#      long_name: Action performed on data
#      conventions: Argo reference table 7
#      _FillValue: b' '
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142, 4)
#  filling on,
#  'HISTORY_PARAMETER': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HISTORY_PARAMETER(N_HISTORY, N_PROF, STRING16)
#      long_name: Station parameter action is performed on
#      conventions: Argo reference table 3
#      _FillValue: b' '
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142, 16)
#  filling on,
#  'HISTORY_START_PRES': <class 'netCDF4._netCDF4.Variable'>
#  float32 HISTORY_START_PRES(N_HISTORY, N_PROF)
#      long_name: Start pressure action applied on
#      _FillValue: 99999.0
#      units: decibar
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142)
#  filling on,
#  'HISTORY_STOP_PRES': <class 'netCDF4._netCDF4.Variable'>
#  float32 HISTORY_STOP_PRES(N_HISTORY, N_PROF)
#      long_name: Stop pressure action applied on
#      _FillValue: 99999.0
#      units: decibar
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142)
#  filling on,
#  'HISTORY_PREVIOUS_VALUE': <class 'netCDF4._netCDF4.Variable'>
#  float32 HISTORY_PREVIOUS_VALUE(N_HISTORY, N_PROF)
#      long_name: Parameter/Flag previous value before action
#      _FillValue: 99999.0
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142)
#  filling on,
#  'HISTORY_QCTEST': <class 'netCDF4._netCDF4.Variable'>
#  |S1 HISTORY_QCTEST(N_HISTORY, N_PROF, STRING16)
#      long_name: Documentation of tests performed, tests failed (in hex form)
#      conventions: Write tests performed when ACTION=QCP$; tests failed when ACTION=QCF$
#      _FillValue: b' '
#  unlimited dimensions: N_HISTORY
#  current shape = (0, 142, 16)
#  filling on}

# %%
for key in list(argo.variables.keys()):
    print(list(argo.variables.keys()).index(key), argo.variables[key][:].dtype, argo.variables[key][:].shape, key)
# Out:
# 0 |S1 (16,) DATA_TYPE
# 1 |S1 (4,) FORMAT_VERSION
# 2 |S1 (4,) HANDBOOK_VERSION
# 3 |S1 (14,) REFERENCE_DATE_TIME
# 4 |S1 (14,) DATE_CREATION
# 5 |S1 (14,) DATE_UPDATE
# 6 |S1 (142, 8) PLATFORM_NUMBER
# 7 |S1 (142, 64) PROJECT_NAME
# 8 |S1 (142, 64) PI_NAME
# 9 |S1 (142, 3, 16) STATION_PARAMETERS
# 10 int32 (142,) CYCLE_NUMBER
# 11 |S1 (142,) DIRECTION
# 12 |S1 (142, 2) DATA_CENTRE
# 13 |S1 (142, 32) DC_REFERENCE
# 14 |S1 (142, 4) DATA_STATE_INDICATOR
# 15 |S1 (142,) DATA_MODE
# 16 |S1 (142, 32) PLATFORM_TYPE
# 17 |S1 (142, 32) FLOAT_SERIAL_NO
# 18 |S1 (142, 32) FIRMWARE_VERSION
# 19 |S1 (142, 4) WMO_INST_TYPE
# 20 float64 (142,) JULD
# 21 |S1 (142,) JULD_QC
# 22 float64 (142,) JULD_LOCATION
# 23 float64 (142,) LATITUDE
# 24 float64 (142,) LONGITUDE
# 25 |S1 (142,) POSITION_QC
# 26 |S1 (142, 8) POSITIONING_SYSTEM
# 27 |S1 (142,) PROFILE_PRES_QC
# 28 |S1 (142,) PROFILE_PSAL_QC
# 29 |S1 (142,) PROFILE_TEMP_QC
# 30 |S1 (142, 256) VERTICAL_SAMPLING_SCHEME
# 31 int32 (142,) CONFIG_MISSION_NUMBER
# 32 float32 (142, 2701) PRES
# 33 |S1 (142, 2701) PRES_QC
# 34 float32 (142, 2701) PRES_ADJUSTED
# 35 |S1 (142, 2701) PRES_ADJUSTED_QC
# 36 float32 (142, 2701) PRES_ADJUSTED_ERROR
# 37 float32 (142, 2701) PSAL
# 38 |S1 (142, 2701) PSAL_QC
# 39 float32 (142, 2701) PSAL_ADJUSTED
# 40 |S1 (142, 2701) PSAL_ADJUSTED_QC
# 41 float32 (142, 2701) PSAL_ADJUSTED_ERROR
# 42 float32 (142, 2701) TEMP
# 43 |S1 (142, 2701) TEMP_QC
# 44 float32 (142, 2701) TEMP_ADJUSTED
# 45 |S1 (142, 2701) TEMP_ADJUSTED_QC
# 46 float32 (142, 2701) TEMP_ADJUSTED_ERROR
# 47 |S1 (142, 3, 3, 16) PARAMETER
# 48 |S1 (142, 3, 3, 256) SCIENTIFIC_CALIB_EQUATION
# 49 |S1 (142, 3, 3, 256) SCIENTIFIC_CALIB_COEFFICIENT
# 50 |S1 (142, 3, 3, 256) SCIENTIFIC_CALIB_COMMENT
# 51 |S1 (142, 3, 3, 14) SCIENTIFIC_CALIB_DATE
# 52 |S1 (0, 142, 4) HISTORY_INSTITUTION
# 53 |S1 (0, 142, 4) HISTORY_STEP
# 54 |S1 (0, 142, 4) HISTORY_SOFTWARE
# 55 |S1 (0, 142, 4) HISTORY_SOFTWARE_RELEASE
# 56 |S1 (0, 142, 64) HISTORY_REFERENCE
# 57 |S1 (0, 142, 14) HISTORY_DATE
# 58 |S1 (0, 142, 4) HISTORY_ACTION
# 59 |S1 (0, 142, 16) HISTORY_PARAMETER
# 60 float32 (0, 142) HISTORY_START_PRES
# 61 float32 (0, 142) HISTORY_STOP_PRES
# 62 float32 (0, 142) HISTORY_PREVIOUS_VALUE
# 63 |S1 (0, 142, 16) HISTORY_QCTEST

# %%
def utf_decoding(array):
    return [x.decode('UTF-8') for x in array.data]

def masked_arrays_decoding(masked_array):
    lst = []
    for idx, row in enumerate(masked_array):
        number = ''.join(utf_decoding(row)).strip()
        lst.append(number)
    return lst

def param_masked_arrays_decoding(masked_array):
    # TODO: improve this horrendous function. The scientific calibrations have 4 dimensions which complicate a bit the automation. 
    calibration = []
    for arrays in range(len(masked_array)):
        lst = []
        for idx, row in enumerate(masked_array[arrays].data):
            temp = []
            for x in range(len(row)):
                temp.append(''.join([y.decode('UTF-8') for y in row[x]]).strip())
            lst.append(temp)
        calibration.append(lst)
    return calibration

tt = {}
for var in list(argo.variables.keys())[:52]: 
    '''
    ['HISTORY_INSTITUTION', 'HISTORY_STEP', 'HISTORY_SOFTWARE', 'HISTORY_SOFTWARE_RELEASE', 'HISTORY_REFERENCE',
    'HISTORY_DATE', 'HISTORY_ACTION', 'HISTORY_PARAMETER', 'HISTORY_START_PRES', 'HISTORY_STOP_PRES', 
    'HISTORY_PREVIOUS_VALUE', 'HISTORY_QCTEST'] (argo.variables.key()[52:]) are empty so we should not bother with them.
    '''
    if len(argo.variables[var][:]) <= 16:
    # Deals with the first variables which have a single information in them e.g. ['DATA_TYPE', 'FORMAT_VERSION', 'HANDBOOK_VERSION', 'REFERENCE_DATE_TIME', 'DATE_CREATION', 'DATE_UPDATE']
        tt[var] = ''.join(utf_decoding(argo.variables[var][:])).strip()
    elif argo.variables[var][:].dtype != '|S1' and argo.variables[var][:].ndim == 1:
        tt[var] = argo.variables[var][:]
    elif argo.variables[var][:].dtype != '|S1' and argo.variables[var][:].ndim > 1:
        tt[var] = list(argo.variables[var][:].data)
    elif argo.variables[var][:].ndim == 1:
        tt[var] = utf_decoding(argo.variables[var][:])
    elif argo.variables[var][:].ndim == 2:
        tt[var] = masked_arrays_decoding(argo.variables[var][:])
    elif argo.variables[var][:].ndim == 3:
        tt[var] = [masked_arrays_decoding(x) for x in argo.variables[var][:]]
    else:
        tt[var] = param_masked_arrays_decoding(argo.variables[var][:])
    
    

argo_df = pd.DataFrame(tt)
argo_df.head()
# Out:
#       DATA_TYPE FORMAT_VERSION HANDBOOK_VERSION REFERENCE_DATE_TIME  \
# 0  Argo profile            3.1              1.2      19500101000000
# 1  Argo profile            3.1              1.2      19500101000000
# 2  Argo profile            3.1              1.2      19500101000000
# 3  Argo profile            3.1              1.2      19500101000000
# 4  Argo profile            3.1              1.2      19500101000000
#
#     DATE_CREATION     DATE_UPDATE PLATFORM_NUMBER     PROJECT_NAME  \
# 0  20200829195536  20200829195536         1901731  US ARGO PROJECT
# 1  20200829195536  20200829195536         1901818  US ARGO PROJECT
# 2  20200829195536  20200829195536         1902184  US ARGO PROJECT
# 3  20200829195536  20200829195536         1902184  US ARGO PROJECT
# 4  20200829195536  20200829195536         1902208  US ARGO PROJECT
#
#                                    PI_NAME  STATION_PARAMETERS  ...  \
# 0  BRECK OWENS, STEVEN JAYNE, P.E. ROBBINS  [PRES, TEMP, PSAL]  ...
# 1  BRECK OWENS, STEVEN JAYNE, P.E. ROBBINS  [PRES, TEMP, PSAL]  ...
# 2  BRECK OWENS, STEVEN JAYNE, P.E. ROBBINS  [PRES, TEMP, PSAL]  ...
# 3  BRECK OWENS, STEVEN JAYNE, P.E. ROBBINS  [PRES, TEMP, PSAL]  ...
# 4  BRECK OWENS, STEVEN JAYNE, P.E. ROBBINS  [PRES, TEMP, PSAL]  ...
#
#                                                 TEMP  \
# 0  [26.675, 26.67, 26.663, 26.662, 26.671, 26.669...
# 1  [27.102, 27.103, 27.103, 27.104, 27.104, 27.10...
# 2  [23.352, 23.352, 23.349, 23.348, 23.355, 23.35...
# 3  [23.377, 23.377, 23.382, 23.392, 23.395, 23.39...
# 4  [19.215, 19.229, 19.234, 19.233, 19.23, 19.226...
#
#                                              TEMP_QC  \
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 4  1111111111111111111111111111111111111111111111...
#
#                                        TEMP_ADJUSTED  \
# 0  [26.675, 26.67, 26.663, 26.662, 26.671, 26.669...
# 1  [27.102, 27.103, 27.103, 27.104, 27.104, 27.10...
# 2  [23.352, 23.352, 23.349, 23.348, 23.355, 23.35...
# 3  [23.377, 23.377, 23.382, 23.392, 23.395, 23.39...
# 4  [99999.0, 99999.0, 99999.0, 99999.0, 99999.0, ...
#
#                                     TEMP_ADJUSTED_QC  \
# 0  1111111111111111111111111111111111111111111111...
# 1  1111111111111111111111111111111111111111111111...
# 2  1111111111111111111111111111111111111111111111...
# 3  1111111111111111111111111111111111111111111111...
# 4
#
#                                  TEMP_ADJUSTED_ERROR  \
# 0  [0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.0...
# 1  [0.002, 0.002, 0.002, 0.002, 0.002, 0.002, 0.0...
# 2  [99999.0, 99999.0, 99999.0, 99999.0, 99999.0, ...
# 3  [99999.0, 99999.0, 99999.0, 99999.0, 99999.0, ...
# 4  [99999.0, 99999.0, 99999.0, 99999.0, 99999.0, ...
#
#                               PARAMETER  \
# 0  [[PRES, TEMP, PSAL], [, , ], [, , ]]
# 1  [[PRES, TEMP, PSAL], [, , ], [, , ]]
# 2  [[PRES, TEMP, PSAL], [, , ], [, , ]]
# 3  [[PRES, TEMP, PSAL], [, , ], [, , ]]
# 4  [[PRES, TEMP, PSAL], [, , ], [, , ]]
#
#                            SCIENTIFIC_CALIB_EQUATION  \
# 0  [[PRES_ADJUSTED = PRES, TEMP_ADJUSTED = TEMP, ...
# 1  [[PRES_ADJUSTED = PRES, TEMP_ADJUSTED = TEMP, ...
# 2  [[none, none, PSAL_ADJUSTED = salinity + salin...
# 3  [[none, none, PSAL_ADJUSTED = salinity + salin...
# 4               [[none, none, none], [, , ], [, , ]]
#
#                         SCIENTIFIC_CALIB_COEFFICIENT  \
# 0  [[None, None, CTM: alpha=0.141C, tau=6.89s, ri...
# 1  [[None, None, CTM: alpha=0.141C, tau=6.89s, ri...
# 2  [[, , salinity_offset =  0.0094105], [, , ], [...
# 3  [[, , salinity_offset =  0.0094105], [, , ], [...
# 4                           [[, , ], [, , ], [, , ]]
#
#                             SCIENTIFIC_CALIB_COMMENT  \
# 0  [[SOLO-W floats auto-correct mild pressure dri...
# 1  [[SOLO-W floats auto-correct mild pressure dri...
# 2  [[, , PSAL ADJUST [dd mm yyyy N S_off stddev] ...
# 3  [[, , PSAL ADJUST [dd mm yyyy N S_off stddev] ...
# 4                           [[, , ], [, , ], [, , ]]
#
#                                SCIENTIFIC_CALIB_DATE
# 0  [[20200825000000, 20200825000000, 202008250000...
# 1  [[20200813000000, 20200813000000, 202008130000...
# 2             [[, , 20200101230048], [, , ], [, , ]]
# 3             [[, , 20200102150028], [, , ], [, , ]]
# 4                           [[, , ], [, , ], [, , ]]
#
# [5 rows x 52 columns]

# %%
# TODO: decide whether expanding all parameters data before or after writing to DB. Param data contains a lot of noise (e.g. 99999.0000 values) 
# Is depth indicated somewhere? or all measures taken at specific depth? TBC from documentation

# %%
import folium
m = folium.Map(location=[50, -60], zoom_start=4.5, tiles='Stamen Terrain')

for flt in argo_df.index:
    folium.Marker(location=[argo_df["LATITUDE"].iloc[flt], argo_df["LONGITUDE"].iloc[flt]]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
temp_df = argo_df[['TEMP']].copy()
temp_df
# Out:
#                                                   TEMP
# 0    [26.675, 26.67, 26.663, 26.662, 26.671, 26.669...
# 1    [27.102, 27.103, 27.103, 27.104, 27.104, 27.10...
# 2    [23.352, 23.352, 23.349, 23.348, 23.355, 23.35...
# 3    [23.377, 23.377, 23.382, 23.392, 23.395, 23.39...
# 4    [19.215, 19.229, 19.234, 19.233, 19.23, 19.226...
# ..                                                 ...
# 137  [4.478, 4.476, 4.475, 4.476, 4.473, 4.475, 4.4...
# 138  [4.35, 4.349, 4.35, 4.352, 4.352, 4.352, 4.352...
# 139  [3.674, 3.68, 3.689, 3.691, 3.691, 3.692, 3.69...
# 140  [14.644, 14.665, 14.678, 14.675, 14.678, 14.68...
# 141  [16.431, 16.442, 16.445, 16.448, 16.441, 16.44...
#
# [142 rows x 1 columns]

# %%
df_temp_test = pd.DataFrame(temp_df['TEMP'].to_list())
df_temp_test = df_temp_test.T.replace(99999.0000, None)
# A lot of temperature lists include 99999.0000 values which we need to get rid of
for col in df_temp_test.columns:
    print(f'{col}: min {df_temp_test[col].min()}, max {df_temp_test[col].max()}, mean {df_temp_test[col].mean()}')
# Out:
# 0: min 5.315000057220459, max 26.690000534057617, mean 6.271593895368071
# 1: min 3.5369999408721924, max 27.106000900268555, mean 4.702252833413354
# 2: min 3.6659998893737793, max 23.368000030517578, mean 5.499650800285495
# 3: min 3.703000068664551, max 23.399999618530273, mean 5.5425627958946695
# 4: min 3.7829999923706055, max 19.236000061035156, mean 5.517728609493246
# 5: min 3.86899995803833, max 25.993000030517578, mean 5.412251720689747
# 6: min 2.447999954223633, max 9.5649995803833, mean 2.8920603186852047
# 7: min 3.746999979019165, max 18.350000381469727, mean 4.848009606106817
# 8: min 3.571000099182129, max 28.097999572753906, mean 4.861038892545421
# 9: min 0.9089999794960022, max 27.136999130249023, mean 3.3207352862716473
# 10: min 14.824000358581543, max 23.94300079345703, mean 14.946489790641392
# 11: min 3.8889999389648438, max 23.940000534057617, mean 5.006264294310439
# 12: min 5.249000072479248, max 24.63599967956543, mean 6.232784584600455
# 13: min 1.7790000438690186, max 25.597999572753906, mean 3.3570474227328337
# 14: min 0.7889999747276306, max 26.29800033569336, mean 3.4030825457984277
# 15: min 0.9390000104904175, max 27.819000244140625, mean 2.4503902350695475
# 16: min 2.191999912261963, max 26.42300033569336, mean 3.4877041150622348
# 17: min 3.7279999256134033, max 25.110000610351562, mean 5.103219931322484
# 18: min 1.9110000133514404, max 26.26799964904785, mean 3.9082240025143586
# 19: min 3.4019999504089355, max 27.364999771118164, mean 4.955597896127514
# 20: min 2.8570001125335693, max 21.5049991607666, mean 4.4082114053893555
# 21: min 3.2920000553131104, max 25.683000564575195, mean 4.869311301278344
# 22: min 3.002000093460083, max 25.333999633789062, mean 4.581688332231077
# 23: min 3.0789999961853027, max 24.868000030517578, mean 4.587074708073548
# 24: min 4.118000030517578, max 25.68400001525879, mean 5.994206981983771
# 25: min 4.914999961853027, max 25.614999771118164, mean 5.925479052464903
# 26: min 8.154000282287598, max 23.121999740600586, mean 10.043445440276116
# 27: min 7.90500020980835, max 25.224000930786133, mean 9.61905052078428
# 28: min 6.363999843597412, max 19.177000045776367, mean 7.715748107420079
# 29: min 5.4720001220703125, max 27.868000030517578, mean 6.818015657323945
# 30: min 5.026000022888184, max 28.43899917602539, mean 6.492735677893538
# 31: min 3.8269999027252197, max 17.485000610351562, mean 5.7621850508400705
# 32: min 3.743000030517578, max 26.51099967956543, mean 6.027490954273765
# 33: min 3.9240000247955322, max 20.05299949645996, mean 6.319001493785876
# 34: min 3.2109999656677246, max 5.828000068664551, mean 3.5497326725547027
# 35: min 4.324999809265137, max 25.820999145507812, mean 5.566566318461119
# 36: min 3.7699999809265137, max 21.38599967956543, mean 6.150171773250966
# 37: min 3.859999895095825, max 22.312999725341797, mean 6.402524926670389
# 38: min 4.309000015258789, max 26.933000564575195, mean 6.4889981599261874
# 39: min 4.284999847412109, max 27.424999237060547, mean 5.899153924615063
# 40: min 4.28000020980835, max 27.15399932861328, mean 5.979524733533863
# 41: min 4.276000022888184, max 27.0310001373291, mean 5.968127333116019
# 42: min -0.08799999952316284, max 2.4649999141693115, mean 1.3715449605364338
# 43: min 2.953000068664551, max 24.875999450683594, mean 3.44640250013564
# 44: min 4.284999847412109, max 23.049999237060547, mean 6.217466372024214
# 45: min 0.5460000038146973, max 2.9240000247955322, mean 1.1265529458366559
# 46: min 2.7892000675201416, max 12.70199966430664, mean 3.460351911486188
# 47: min 2.705699920654297, max 21.53700065612793, mean 4.300268466540594
# 48: min 2.865999937057495, max 17.06599998474121, mean 4.039161029721754
# 49: min 2.7950000762939453, max 17.466999053955078, mean 3.3618300929417306
# 50: min -0.31700000166893005, max 2.2799999713897705, mean 1.003288780350441
# 51: min 2.825000047683716, max 25.191999435424805, mean 3.038365836851423
# 52: min 2.8919999599456787, max 23.764999389648438, mean 3.1015591224181747
# 53: min 2.7790000438690186, max 15.491000175476074, mean 2.9085768658511952
# 54: min 3.0878000259399414, max 20.913999557495117, mean 4.535917164881289
# 55: min 3.249000072479248, max 26.128000259399414, mean 3.482494343655589
# 56: min 3.0369999408721924, max 23.30900001525879, mean 5.033349829751092
# 57: min 0.5680000185966492, max 2.9070000648498535, mean 0.7034161468427829
# 58: min 2.631999969482422, max 11.236000061035156, mean 2.7783261463846025
# 59: min 3.5490000247955322, max 23.650999069213867, mean 3.733597952716662
# 60: min 3.440000057220459, max 7.826000213623047, mean 3.4831196828402224
# 61: min -0.0010000000474974513, max 11.083999633789062, mean 7.977399645486365
# 62: min 3.4100000858306885, max 5.985000133514404, mean 3.4362051936265763
# 63: min 3.5179998874664307, max 9.63599967956543, mean 3.5821868576239058
# 64: min 3.3180999755859375, max 11.736700057983398, mean 4.823921383243718
# 65: min 3.25600004196167, max 7.201000213623047, mean 3.348077418935692
# 66: min 3.9240000247955322, max 24.20599937438965, mean 4.166669035875898
# 67: min 2.165299892425537, max 24.62420082092285, mean 5.2950526878861135
# 68: min 3.571000099182129, max 11.10200023651123, mean 3.7032651820918976
# 69: min 3.6019999980926514, max 13.78600025177002, mean 3.7708145106822992
# 70: min 3.8510000705718994, max 22.50200080871582, mean 4.110809396611722
# 71: min 3.7850000858306885, max 20.305999755859375, mean 4.120071541331777
# 72: min 3.2699999809265137, max 4.914999961853027, mean 3.2937074975144727
# 73: min 3.3269999027252197, max 5.59499979019165, mean 3.357587095544498
# 74: min 3.3731000423431396, max 4.617700099945068, mean 3.4961772695023763
# 75: min 4.183000087738037, max 27.766000747680664, mean 6.211800127548449
# 76: min 3.5799999237060547, max 27.884000778198242, mean 3.823845539124795
# 77: min 3.056999921798706, max 24.76300048828125, mean 3.433568680123107
# 78: min 4.190000057220459, max 19.253999710083008, mean 4.444082247067804
# 79: min 3.3320000171661377, max 26.759000778198242, mean 3.609964475239793
# 80: min 13.779000282287598, max 18.176000595092773, mean 13.96372768976917
# 81: min -0.7429999709129333, max 5.269999980926514, mean -0.22021323201197943
# 82: min 3.9019999504089355, max 25.65999984741211, mean 4.809367598007891
# 83: min 25.731000900268555, max 25.731000900268555, mean 25.731000900268555
# 84: min 99999.0, max 99999.0, mean 99999.0
# 85: min 3.4119999408721924, max 3.437999963760376, mean 3.4120095669450867
# 86: min 3.868000030517578, max 22.854000091552734, mean 4.104883776643196
# 87: min 4.353000164031982, max 19.125, mean 4.597699530784045
# 88: min 3.5409998893737793, max 27.965999603271484, mean 4.073139473933813
# 89: min 4.127999782562256, max 21.437999725341797, mean 4.429870581459178
# 90: min 3.7149999141693115, max 24.900999069213867, mean 4.045492328126887
# 91: min 3.187999963760376, max 6.381999969482422, mean 3.2296786018761385
# 92: min 13.776000022888184, max 18.33099937438965, mean 14.157934236861918
# 93: min 13.807999610900879, max 18.718000411987305, mean 14.25669321789648
# 94: min 8.461000442504883, max 13.006999969482422, mean 9.027198328260402
# 95: min -0.4779999852180481, max 6.315000057220459, mean -0.39606847865758715
# 96: min 3.552000045776367, max 13.361000061035156, mean 3.714819000986319
# 97: min 3.7100000381469727, max 28.639999389648438, mean 3.9018708248131366
# 98: min 3.6089999675750732, max 13.267000198364258, mean 3.7635338439715436
# 99: min 3.632999897003174, max 11.354999542236328, mean 3.7843264453899237
# 100: min 3.3450000286102295, max 4.497000217437744, mean 3.367485764731923
# 101: min 4.3470001220703125, max 22.858999252319336, mean 7.408416964839185
# 102: min 3.6659998893737793, max 14.348999977111816, mean 3.8516104103061544
# 103: min 4.2789998054504395, max 17.128999710083008, mean 4.63520758490084
# 104: min 3.5350000858306885, max 27.367000579833984, mean 3.7578294057397654
# 105: min 2.9539999961853027, max 20.608999252319336, mean 3.160646792739817
# 106: min 3.5380001068115234, max 28.63800048828125, mean 3.8154706698088945
# 107: min 14.01099967956543, max 20.082000732421875, mean 14.53955582961556
# 108: min 4.276000022888184, max 25.865999221801758, mean 6.8427560358566515
# 109: min 4.284999847412109, max 25.832000732421875, mean 6.940357179122693
# 110: min 4.2829999923706055, max 23.514999389648438, mean 6.383507954549101
# 111: min 4.283999919891357, max 24.81399917602539, mean 6.49288101842429
# 112: min 13.78600025177002, max 16.823999404907227, mean 14.068471458036782
# 113: min 13.756999969482422, max 18.954999923706055, mean 14.14412673638071
# 114: min 13.788999557495117, max 16.40399932861328, mean 14.056466769218797
# 115: min 13.270000457763672, max 14.996000289916992, mean 13.377256554791064
# 116: min 13.378000259399414, max 15.616000175476074, mean 13.620643995285741
# 117: min 15.369000434875488, max 18.246999740600586, mean 15.46422698399792
# 118: min 13.164999961853027, max 14.414999961853027, mean 13.308033135677876
# 119: min 13.0649995803833, max 16.1560001373291, mean 13.124553839306794
# 120: min 13.812000274658203, max 18.775999069213867, mean 14.143244587638033
# 121: min 13.892000198364258, max 19.07699966430664, mean 13.995347467893497
# 122: min -1.1729999780654907, max 2.819000005722046, mean -0.298425024576471
# 123: min -0.5709999799728394, max 0.6899999976158142, mean -0.4143965039430262
# 124: min -0.5860000252723694, max 5.591000080108643, mean 0.6065042374711808
# 125: min 2.6570000648498535, max 4.623899936676025, mean 4.609423076784289
# 126: min 2.7679998874664307, max 24.25200080871582, mean 2.9617973729797047
# 127: min 2.805000066757202, max 17.507999420166016, mean 2.9891751847060597
# 128: min 3.51200008392334, max 29.051000595092773, mean 3.687648359293057
# 129: min 2.5309998989105225, max 10.065999984741211, mean 2.5919265955388657
# 130: min 5.435999870300293, max 24.29990005493164, mean 6.526139248392838
# 131: min 5.605000019073486, max 22.794200897216797, mean 6.519868915851625
# 132: min 6.2444000244140625, max 13.871700286865234, mean 6.538604648940345
# 133: min 8.437999725341797, max 11.067999839782715, mean 8.958714945940388
# 134: min 2.615000009536743, max 13.508999824523926, mean 2.7225649847625935
# 135: min 3.9719998836517334, max 22.628999710083008, mean 5.9298003561979575
# 136: min 3.6029999256134033, max 17.152999877929688, mean 4.734687110310526
# 137: min 3.3440001010894775, max 4.478000164031982, mean 3.4590373880463323
# 138: min 3.322999954223633, max 4.355999946594238, mean 3.436786305414487
# 139: min 3.2980000972747803, max 4.065999984741211, mean 3.4717100649928656
# 140: min 3.499000072479248, max 15.993000030517578, mean 3.6635135833707753
# 141: min 3.437000036239624, max 17.111000061035156, mean 3.633506883651581

# %%
temp_df = argo_df[['LATITUDE', 'LONGITUDE']]
temp_df['MEAN_TPT'] = pd.Series([df_temp_test[col].mean() for col in df_temp_test.columns])
temp_df
# Out:
# C:\Users\Kik\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       LATITUDE  LONGITUDE  MEAN_TPT
# 0     9.201430 -37.727650  6.271594
# 1    -6.972160  -9.659960  4.702253
# 2    19.470060 -30.365670  5.499651
# 3    19.456280 -30.361650  5.542563
# 4    22.753110 -18.078970  5.517729
# ..         ...        ...       ...
# 137  54.006447 -50.540653  3.459037
# 138  58.633392 -39.617931  3.436786
# 139  57.910954 -54.497654  3.471710
# 140  41.499115 -49.142590  3.663514
# 141  42.708710 -48.856682  3.633507
#
# [142 rows x 3 columns]

# %%
from folium.plugins import HeatMap
HeatMap(data=temp_df[['LATITUDE', 'LONGITUDE', 'MEAN_TPT']].groupby(['LATITUDE', 'LONGITUDE']).sum().reset_index().values.tolist(), radius=25, max_zoom=10).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# TODO: continue looking at https://shapely.readthedocs.io/en/latest/manual.html to find ways to divide multipolygon files into sub-areas. Seem to not be trivial outside of ArcGIS/QGIS.
